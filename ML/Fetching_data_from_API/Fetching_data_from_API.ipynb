# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
df = pd.DataFrame(response.json()["results"])

# %%
df = df[["id", "title", "overview", "release_date", "popularity"]]

# %%
df
# Out:
#          id                                          title  \
# 0       278                       The Shawshank Redemption
# 1       238                                  The Godfather
# 2       240                          The Godfather Part II
# 3       424                               Schindler's List
# 4       389                                   12 Angry Men
# 5   1181678                          ¿Quieres ser mi hijo?
# 6       129                                  Spirited Away
# 7       155                                The Dark Knight
# 8     19404                    Dilwale Dulhania Le Jayenge
# 9       497                                 The Green Mile
# 10   496243                                       Parasite
# 11      122  The Lord of the Rings: The Return of the King
# 12      680                                   Pulp Fiction
# 13   372058                                     Your Name.
# 14   157336                                   Interstellar
# 15      429                 The Good, the Bad and the Ugly
# 16       13                                   Forrest Gump
# 17      769                                     GoodFellas
# 18      346                                  Seven Samurai
# 19    12477                         Grave of the Fireflies
#
#                                              overview release_date  popularity
# 0   Imprisoned in the 1940s for the double murder ...   1994-09-23     38.3467
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     34.9917
# 2   In the continuing saga of the Corleone crime f...   1974-12-20     19.4661
# 3   The true story of how businessman Oskar Schind...   1993-12-15     19.3480
# 4   The defense and the prosecution have rested an...   1957-04-10     17.6774
# 5   Lu, a conformist woman in her forties, learns ...   2023-09-21      5.6660
# 6   A young girl, Chihiro, becomes trapped in a st...   2001-07-20     27.7621
# 7   Batman raises the stakes in his war on crime. ...   2008-07-16     40.7707
# 8   Raj is a rich, carefree, happy-go-lucky second...   1995-10-20     16.3979
# 9   A supernatural tale set on death row in a Sout...   1999-12-10     19.4247
# 10  All unemployed, Ki-taek's family takes peculia...   2019-05-30     25.7258
# 11  As armies mass for a final battle that will de...   2003-12-17     26.4186
# 12  A burger-loving hit man, his philosophical par...   1994-09-10     23.3183
# 13  High schoolers Mitsuha and Taki are complete s...   2016-08-26     22.9310
# 14  The adventures of a group of explorers who mak...   2014-11-05     51.9612
# 15  While the Civil War rages on between the Union...   1966-12-23     18.9398
# 16  A man with a low IQ has accomplished great thi...   1994-06-23     25.9672
# 17  The true story of Henry Hill, a half-Irish, ha...   1990-09-12     19.8633
# 18  A samurai answers a village's request for prot...   1954-04-26      9.2682
# 19  In the final months of World War II, 14-year-o...   1988-04-16      0.0125

# %%
new_df = pd.DataFrame()

# %%
new_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 429):
    response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}", format(i))
    temp_df = pd.DataFrame(response.json()["results"])[["id", "title", "overview", "release_date", "popularity"]]
    new_df = new_df.append(temp_df, ignore_index=True)

# %%
new_df
