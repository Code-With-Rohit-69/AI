# %%
import numpy as np
import pandas as pd

# %%
dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, np.nan, 98]}

df = pd.DataFrame(dict)

# %%
df
# Out:
#      name  degree  score
# 0  aparna     MBA   90.0
# 1  pankaj     BCA   40.0
# 2  sudhir  M.Tech    NaN
# 3   Geeku     MBA   98.0

# %%
df.isna()
# Out:
#     name  degree  score
# 0  False   False  False
# 1  False   False  False
# 2  False   False   True
# 3  False   False  False

# %%
df.isna().sum()
# Out:
# name      0
# degree    0
# score     1
# dtype: int64

# %%
df
# Out:
#      name  degree  score
# 0  aparna     MBA   90.0
# 1  pankaj     BCA   40.0
# 2  sudhir  M.Tech    NaN
# 3   Geeku     MBA   98.0

# %%
df.dropna()
# Out:
#      name degree  score
# 0  aparna    MBA   90.0
# 1  pankaj    BCA   40.0
# 3   Geeku    MBA   98.0

# %%
df
# Out:
#      name  degree  score
# 0  aparna     MBA   90.0
# 1  pankaj     BCA   40.0
# 2  sudhir  M.Tech    NaN
# 3   Geeku     MBA   98.0

# %%
df.fillna(0)
# Out:
#      name  degree  score
# 0  aparna     MBA   90.0
# 1  pankaj     BCA   40.0
# 2  sudhir  M.Tech    0.0
# 3   Geeku     MBA   98.0

# %%
df
# Out:
#      name  degree  score
# 0  aparna     MBA   90.0
# 1  pankaj     BCA   40.0
# 2  sudhir  M.Tech    NaN
# 3   Geeku     MBA   98.0

# %%
values = {'A': 0, 'B': 100, 'score': 300, 'D': 400}
df.fillna(value=values)
# Out:
#      name  degree  score
# 0  aparna     MBA   90.0
# 1  pankaj     BCA   40.0
# 2  sudhir  M.Tech  300.0
# 3   Geeku     MBA   98.0
