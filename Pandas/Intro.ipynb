# %%
import numpy as np
import pandas as pd

# %%
labels = ['A', 'B', 'C']
my_list = [10, 20, 30]
array = np.array([10, 20, 30])

pd.Series(my_list, index=labels)
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %%
pd.Series(array)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
dict_ = {'a': 100, 'b': 200, 'c': 300}

pd.Series(dict_)
# Out:
# a    100
# b    200
# c    300
# dtype: int64
