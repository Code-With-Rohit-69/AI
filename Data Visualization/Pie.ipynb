# %%
import matplotlib.pyplot as plt

# %%
regions = ["North", "East", "West", "South"]
revenue = [2000, 3000, 4000, 1000]

plt.pie(revenue, labels=regions, colors = ["#4C2dB0", "#DD8452", "#55A868", "#C44E52"]
)

plt.show()
