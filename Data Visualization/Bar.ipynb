# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 6, 1)
y = np.arange(100, 600, 100)

plt.bar(x, y, label="Data")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.legend()

plt.show()

# %%
fruits = ["Apples", "Bananas", "Cherries", "Dates"]
sales = [400, 350, 300, 450]

plt.bar(fruits, sales, color="violet")
plt.title("Fruit Sales")
plt.xlabel("Fruits")
plt.ylabel("Sales")


plt.show()

# %%
fruits = ["Apples", "Bananas", "Cherries", "Dates"]
sales = [400, 350, 300, 450]

plt.barh(fruits, sales, color="violet")
plt.title("Fruit Sales")
plt.ylabel("Fruits")
plt.xlabel("Sales")


plt.show()

# %%
fruits = ["Apples", "Bananas", "Cherries", "Dates"]
sales = [400, 350, 300, 450]

plt.bar(fruits, sales, color="orange", width=.4, label="Fruits Bar")
plt.title("Fruit Sales")
plt.xlabel("Fruits")
plt.ylabel("Sales")

plt.legend()

plt.show()
